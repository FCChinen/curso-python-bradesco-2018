# %%
import numpy as np

x = np.array([-2.5,  -2, -1.76,  -1, -0.2, 0.5, 0.8, 1.0, 1.1]).reshape(-1, 1)
x = x ** np.arange(2)
print(x)
# Out:
# [[ 1.   -2.5 ]
#  [ 1.   -2.  ]
#  [ 1.   -1.76]
#  [ 1.   -1.  ]
#  [ 1.   -0.2 ]
#  [ 1.    0.5 ]
#  [ 1.    0.8 ]
#  [ 1.    1.  ]
#  [ 1.    1.1 ]]
